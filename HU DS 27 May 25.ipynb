# %% [markdown]
# This is where we can enter some text about our project.
# # <b>Big title</b>
# ## **Substitle or section title**
# ### *Subsection*
# #### Another section
# ##### Smallest section title.
#
#
#
# ```
# print("I am an HBCU Scholar!")
# ```
# $$\sum_{n=1}^{10} \log \frac{6n+7j}{3n}$$
#
# * This is some bullet text
# * Adding additional text
# * Last point of interest

# %%
# Let's create our first print statement
print("Hello, Black World!")
# Out:
# Hello, Black World!

# %%
# Same code with the single quotes
print('Hello, Black World!')
# Out:
# Hello, Black World!

# %%
# Let's print the value of pi from the math module
# Import the math module
import math
#Print the value of pi from the math module.
print(math.pi)
# Out:
# 3.141592653589793

# %%
import math

# %%
# Let's create a variable with the value of pi from the math module
pi = math.pi

# %%
# Print the value stored in the variable pi
print(pi)
# Out:
# 3.141592653589793

# %%
# Print the value stored in the variable pi
pi
# Out:
# 3.141592653589793

# %%
""" Let's print the statement the value of pi is
with the value stored in the variable pi."""
print("The value of pi is: ", pi)
# Out:
# The value of pi is:  3.141592653589793

# %%
""" Let's print the statement the value of pi is
with the value stored in the variable pi."""
print("The value of pi is: \n",
      pi)
# Out:
# The value of pi is:
#  3.141592653589793

# %%
print("Supercalifrbhajdjfkesjfjefjjsjsjdjfhjdhshsjdsjfdjfh")
# Out:
# Supercalifrbhajdjfkesjfjefjjsjsjdjfhjdhshsjdsjfdjfh

# %%
# Using input statement
name = input(print("Please enter your first name: "))
print(name)
# Out:
# Please enter your first name:
# None123981298721498412
# 123981298721498412

# %%
# How do I see the information on a method?
math.pi?

# %% [markdown]
# This pops up in a separate window to the right in Colab. You call the method or library name and follow with a question mark. Alternatively you cann use the `help()` method in Python to view help for the method.

# %%
# Using help() to find out more info
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...
